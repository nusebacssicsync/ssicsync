# %% [markdown]
# ### Libraries and Files

# %%
import pandas as pd
import warnings
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
from nltk.tokenize import word_tokenize

warnings.filterwarnings("ignore")
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# %%
df = pd.read_csv('/Users/Michael/Documents/GitHub/ssicsync/Webscrap/Webscrape from Linkedin.csv')
ref = pd.read_csv('/Users/Michael/Documents/GitHub/ssicsync/Webscrap/List of 90 Coy and SSIC.csv', dtype={'ssic_code': str})
ssic = pd.read_excel('/Users/Michael/Documents/GitHub/ssicsync/ssic2020-detailed-definitions.xlsx', skiprows=[0,1,2,3], usecols=[0,1,3,5], dtype={'SSIC 2020': str})
pdf = pd.read_excel('C:/Users/Michael/Documents/GitHub/ssicsync/Webscrap/AR Report Data/extracted_notes_pages_with_uen.xlsx')

# %%
linkedInModelResults_path = '/Users/Michael/Documents/GitHub/ssicsync/recommendationModels/linkedInFullModelResults.xlsx'
linkedInModel_path = '/Users/Michael/Documents/GitHub/ssicsync/recommendationModels/linkedInModel'

pdfModelResults_path = '/Users/Michael/Documents/GitHub/ssicsync/recommendationModels/pdfFullModelResults.xlsx'
pdfModel_path = '/Users/Michael/Documents/GitHub/ssicsync/recommendationModels/pdfModel'

linkedInPdfModelResults_path = '/Users/Michael/Documents/GitHub/ssicsync/recommendationModels/linkedInPdfFullModelResults.xlsx'
linkedInPdfModel_path = '/Users/Michael/Documents/GitHub/ssicsync/recommendationModels/linkedInPdfModel'

# %% [markdown]
# ### Recommender Model Function

# %%
def recommendationModel(df = None, ssic = None, withSSIC = True, epochs = 40, vector_size = 64, top = 5, trainPercentage_0to1 = 0.7):

    df['ssic_code'] = df['ssic_code'].astype(str).str.zfill(5)
    df.reset_index(drop = True, inplace = True)

    # 70-30 Train-Test split (randomised selection):
    train = df.sample(round(df.shape[0]*trainPercentage_0to1)).reset_index(drop = True)
    test = df[~df.Company.isin(train.Company)].reset_index(drop = True)

    if withSSIC == True:
        # NOTE include line below if want to add original SSIC text reference into training data:
        ssic.reset_index(drop = True, inplace = True)
        train = pd.concat([train, ssic], axis = 0).reset_index(drop = True)

    # Model training
    textonly = train['Text Content']
    text_tokens = [word_tokenize(t.lower()) for t in textonly]
    tagged_data = [TaggedDocument(d, [i]) for i, d in enumerate(text_tokens)]
    model = Doc2Vec(vector_size=vector_size, min_count=2, epochs=epochs)
    model.build_vocab(tagged_data)
    model.train(tagged_data, total_examples=model.corpus_count, epochs=epochs)

    # Parsing model outputs into a df (with dups)
    recsys_df = pd.DataFrame(columns = ["Company", "actualSSIC", "recSSIC", "score", "actualTextContent", "recommendedTextContent"])
    for index, series in test.iterrows():
        test_doc = word_tokenize(series['Text Content'].lower())
        test_vec = model.infer_vector(test_doc)
        results = model.docvecs.most_similar(positive=[test_vec], topn=top)
        for i, (index, similarity_score) in enumerate(results):
            coy = series["Company"]
            actualssic = series['ssic_code']
            recssic = train["ssic_code"][index]
            actualTextContent = series["Text Content"]
            recommendedTextContent = train["Text Content"][index]
            score = similarity_score
            row = [coy, actualssic, recssic, score, actualTextContent, recommendedTextContent]
            recsys_df.loc[len(recsys_df)] = row
    recsys_df['rank'] = recsys_df.sort_values(by = ['Company', 'score'], ascending=[True, False]).groupby('Company').cumcount()+1
    recsysForValidation_df = recsys_df.copy()
    training_df = train.copy()
    testing_df = test.copy()

    recsys_df.drop(columns = ["actualTextContent", "recommendedTextContent"], inplace = True)
    recsys_df['actualSSIC'] = recsys_df['actualSSIC'].apply(lambda x: x[0:2])
    recsys_df['recSSIC'] = recsys_df['recSSIC'].apply(lambda x: x[0:2])

    recsysForValidation_df['actualSSICDescription'] = ''
    recsysForValidation_df['recSSICDescription'] = ''
    for index, series in recsysForValidation_df.iterrows():
        ssicGrouped = ssic.groupby('ssic_code')['Text Content'].apply(lambda x: ' '.join(x)).reset_index()

        try:    
            actualSSICDescription = ssicGrouped[ssicGrouped.ssic_code == series.actualSSIC].reset_index(drop=True)['Text Content'].values[0]
            recsysForValidation_df.loc[index, 'actualSSICDescription'] = actualSSICDescription
        except Exception as e:
            print('actualSSICDescription:')
            print(ssicGrouped[ssicGrouped.ssic_code == series.actualSSIC].reset_index(drop=True)['Text Content'])
            print(f"Error: {e}")
            print(f"SSIC in Master List: {series.actualSSIC}")

        try:
            recSSICDescription = ssicGrouped[ssicGrouped.ssic_code == series.recSSIC].reset_index(drop=True)['Text Content'].values[0]
            recsysForValidation_df.loc[index, 'recSSICDescription'] = recSSICDescription
        except Exception as e:
            print('recSSICDescription:')
            print(ssicGrouped[ssicGrouped.ssic_code == series.actualSSIC].reset_index(drop=True)['Text Content'])
            print(f"Error: {e}")
            print(f"SSIC in Master List: {series.actualSSIC}")

    recsysForValidation_df = recsysForValidation_df[['Company', 'actualSSIC', 'recSSIC', 'score', 'rank', 'actualTextContent', 'recommendedTextContent', 'actualSSICDescription', 'recSSICDescription']]

    #########################################
    
    recsysAccuracy_df = recsys_df.copy()

    print('Model Results:')
    recsysAccuracy_df.loc[recsysAccuracy_df.actualSSIC == recsysAccuracy_df.recSSIC, 'match'] = 1
    recsysAccuracy_df.loc[recsysAccuracy_df.match != 1, 'match'] = 0
    recsysAccuracy_df = recsysAccuracy_df.sort_values(by = ['Company', 'match'], ascending=False).groupby('Company').head(1).reset_index(drop = True)
    matchAccuracy = len(recsysAccuracy_df[recsysAccuracy_df.match == 1].match)/recsysAccuracy_df.shape[0]
    print(f'Accuracy of Recommendation Model: {round(matchAccuracy*100,1)}%')

    print(f"Overall Similarity Score: {round(recsys_df.score.mean(),2)} out of 1.00")

    recsysStats_df = recsys_df.copy()
    recsysStats_df['recSSIC'] = recsysStats_df['recSSIC'].astype('int64')
    recsysStats_df = recsysStats_df.groupby('Company')['recSSIC'].agg(['mean', 'std']).reset_index()
    print(f"Overall Stats (99 Divisions in Total):\n{round(recsysStats_df.mean(),1)}")

    print_statements = {
    "Evaluation Metrics": ["Overall Accuracy", "Similarity Score (Average)", "Mean (99 Divisions in Total)", "Standard Deviation (99 Divisions in Total)"],
    "Values": [f"{matchAccuracy}", f"{recsys_df.score.mean()}", f"{recsysStats_df['mean'].mean()}", f"{recsysStats_df['std'].mean()}"]
    }
    modelResults_df = pd.DataFrame(print_statements)

    return recsys_df, recsysStats_df, recsysForValidation_df, training_df, testing_df, model, modelResults_df

# %%
for column in ssic.columns:
    ssic.loc[((ssic[column] == '<Blank>') | (ssic[column].isnull())), column] = ''
ssic = ssic[~ssic['SSIC 2020'].str.match(r'^[A-Z]$')]

# just predicting up to Division level in the SSIC code
# ssic['SSIC 2020'] = ssic['SSIC 2020'].apply(lambda x: str(x)[0:2])

# Define a cleaning function
def clean_text(text):
    if isinstance(text, str):
        # Replace newline characters with space
        text = text.replace('\n', ' ')
        # Replace special characters (bullet points) with a consistent delimiter
        text = text.replace('•', '- ')
        # Strip leading and trailing whitespace
        text = text.strip()
        # Replace multiple spaces with a single space
        text = ' '.join(text.split())
    return text

# Apply the cleaning function to the 'Info' column
ssic['Detailed Definitions'] = ssic['Detailed Definitions'].apply(clean_text)
ssic['Examples of Activities Classified Under this Code'] = ssic['Examples of Activities Classified Under this Code'].apply(clean_text)

ssic['textonly'] = ssic['SSIC 2020 Title'] + '.' + ssic['Detailed Definitions'] + '.' + ssic['Examples of Activities Classified Under this Code']
ssic = ssic[['SSIC 2020', 'textonly']]
ssic.columns = ['ssic_code', 'Text Content']
ssic = ssic[ssic['Text Content'].notnull()]

# %% [markdown]
# ### LinkedIn

# %%
# Step 1: Remove leading and trailing whitespace
df['Text Content'] = df['Text Content'].str.strip()

# Step 2: Replace newline characters with spaces
df['Text Content'] = df['Text Content'].str.replace('\r\n', ' ', regex=False)
df['Text Content'] = df['Text Content'].str.replace('\n', ' ', regex=False)

# Step 3: Fill missing values with a placeholder
# df['Text Content'] = df['Text Content'].fillna('')

# Optional Step 4: Normalize text by converting to lowercase (if needed)
df['Text Content'] = df['Text Content'].str.lower()

# %%
ref.rename(columns = {'entity_name': 'Company'}, inplace = True)
ref = ref.sort_values(by = ['Company', 'ssic_code']).drop_duplicates(subset = 'Company', keep = 'first')
ref = ref[['Company', 'ssic_code', 'UEN']]

test = pd.merge(df, ref, how = 'left', on = 'Company')

# %%
# NOTE There's discrepency in PDFs vs 'List of 90 Coy and SSIC' company names (12 companies missing) ..
# .. [Most were resolved by putting a '.' to List of 90 Coy and SSIC's df]
ref['Company'] = ref['Company'].apply(lambda x: x[:-1] if x[-1] == '.' else x)

test2 = pd.merge(test[test.ssic_code.isnull()], ref, how = 'left', on = 'Company')
test2.drop(columns='ssic_code_x', inplace = True)
test2.rename(columns={'ssic_code_y':'ssic_code'}, inplace = True)

# %%
# NOTE Web scrapping codes is taking the first profile in the search page, which may be the wrong company. Hence, scrapped info may be wrong.
## ACCRELIST LTD linkedin info seems wrong, but pdf and List of 90 Coy and SSIC's df seems correct (misaligned names!) ..
## TODO Probably should webscrape using the names from List of 90 Coy and SSIC's df instead of pdf names (since it's the source of truth for SSIC codes)?
df = pd.concat([test[~ test.ssic_code.isnull()], test2], axis = 0)

# NOTE Out of 90 coys, ..
## .. 18 has no LinkedIn content, ..
## .. 1 has PDF but not in List of 90 Coy and SSIC's df (ACMA LTD), ..
## .. 1 has PDF and in List of 90 Coy and SSIC's df (ACMA LTD) but partially different name (ACCRELIST LTD) [hence can't match to get SSIC codes!]
df = df[['Company', 'ssic_code', 'Text Content']][(df.ssic_code.notnull()) & (df['Text Content'].notnull())].reset_index(drop = True)

# %%
accuracy = 0
for i in range(1,11):
# while accuracy < 0.55:
    recsys_df, recsysStats_df, recsysForValidation_df, training_df, testing_df, model, modelResults_df = recommendationModel(df = df, ssic = ssic,
                                                                                                    withSSIC = True, epochs = 40, vector_size = 64,
                                                                                                    top = 5, trainPercentage_0to1 = 0.7)
    accuracy = float(modelResults_df.head(1)['Values'].values[0])

# Create files
with pd.ExcelWriter(linkedInModelResults_path) as writer:
    modelResults_df.to_excel(writer, sheet_name='Model Results', index=False)
    recsys_df.to_excel(writer, sheet_name='Model Outputs', index=False)
    recsysStats_df.to_excel(writer, sheet_name='Model Stats', index=False)
    recsysForValidation_df.to_excel(writer, sheet_name='Model Validation', index=False)
    training_df.to_excel(writer, sheet_name='Training Data', index=False)
    testing_df.to_excel(writer, sheet_name='Testing Data', index=False)
model.save(linkedInModel_path)

# TODO
# we talk about linkedin first for now
# what are the companies that are matched wrongly? any patterns? could be business user declaration and way of writing mismatches the business activity. maybe there's prob with source of truth. maybe sample issue skewed against certain ssic fields
# Out:
# Model Results:
# Accuracy of Recommendation Model: 38.1%
# Overall Similarity Score: 0.54 out of 1.00
# Overall Stats (99 Divisions in Total):
# mean    49.5
# std     20.2
# dtype: float64
# Model Results:
# Accuracy of Recommendation Model: 47.6%
# Overall Similarity Score: 0.61 out of 1.00
# Overall Stats (99 Divisions in Total):
# mean    51.3
# std     15.6
# dtype: float64
# Model Results:
# Accuracy of Recommendation Model: 47.6%
# Overall Similarity Score: 0.57 out of 1.00
# Overall Stats (99 Divisions in Total):
# mean    42.9
# std     14.7
# dtype: float64
# Model Results:
# Accuracy of Recommendation Model: 33.3%
# Overall Similarity Score: 0.58 out of 1.00
# Overall Stats (99 Divisions in Total):
# mean    44.3
# std     16.6
# dtype: float64
# Model Results:
# Accuracy of Recommendation Model: 38.1%
# Overall Similarity Score: 0.55 out of 1.00
# Overall Stats (99 Divisions in Total):
# mean    49.2
# std     21.7
# dtype: float64
# Model Results:
# Accuracy of Recommendation Model: 33.3%
# Overall Similarity Score: 0.58 out of 1.00
# Overall Stats (99 Divisions in Total):
# mean    48.6
# std     17.5
# dtype: float64
# Model Results:
# Accuracy of Recommendation Model: 38.1%
# Overall Similarity Score: 0.55 out of 1.00
# Overall Stats (99 Divisions in Total):
# mean    50.0
# std     18.4
# dtype: float64
# Model Results:
# Accuracy of Recommendation Model: 47.6%
# Overall Similarity Score: 0.59 out of 1.00
# Overall Stats (99 Divisions in Total):
# mean    51.9
# std     21.4
# dtype: float64
# Model Results:
# Accuracy of Recommendation Model: 28.6%
# Overall Similarity Score: 0.56 out of 1.00
# Overall Stats (99 Divisions in Total):
# mean    46.7
# std     17.7
# dtype: float64
# Model Results:
# Accuracy of Recommendation Model: 42.9%
# Overall Similarity Score: 0.57 out of 1.00
# Overall Stats (99 Divisions in Total):
# mean    48.2
# std     15.4
# dtype: float64

# %% [markdown]
# ### Annual Reports

# %%
pdf = pdf[['PDF Name', 'UEN Number', 'Notes Page Content']]
pdf.columns = ['Company', 'UEN', 'Text Content']

# %%
pdf = pd.merge(pdf,ref[['ssic_code', 'UEN']], how = 'left', on = 'UEN')
pdf = pdf[['Company', 'ssic_code', 'Text Content']]

# %%
# Extracting only the name part into a new column
pdf['Company'] = pdf['Company'].apply(lambda x: ' '.join(x.split(' ')[:-1])[:-5].strip() if '.' in x else x[:-9].strip())
pdf['Company'] = pdf['Company'].apply(lambda x: x[:-1] if x[-1] == '.' else x)

# %%
accuracy = 0
for i in range(1,11):
# while accuracy < 0.55:
    recsys_df, recsysStats_df, recsysForValidation_df, training_df, testing_df, model, modelResults_df = recommendationModel(df = pdf, ssic = ssic,
                                                                                                    withSSIC = True, epochs = 40, vector_size = 64,
                                                                                                    top = 5, trainPercentage_0to1 = 0.7)
    accuracy = float(modelResults_df.head(1)['Values'].values[0])

# Create files
with pd.ExcelWriter(pdfModelResults_path) as writer:
    modelResults_df.to_excel(writer, sheet_name='Model Results', index=False)
    recsys_df.to_excel(writer, sheet_name='Model Outputs', index=False)
    recsysStats_df.to_excel(writer, sheet_name='Model Stats', index=False)
    recsysForValidation_df.to_excel(writer, sheet_name='Model Validation', index=False)
    training_df.to_excel(writer, sheet_name='Training Data', index=False)
    testing_df.to_excel(writer, sheet_name='Testing Data', index=False)
model.save(pdfModel_path)
# Out:
# recSSICDescription:
# 0    Manufacture of petroleum lubricating oil.This Sub-class includes manufacture of petroleum lubricating oil. Units in this Sub-class are primarily engaged in blending or compounding refined petroleum to make lubricating oils and greases and/or re-refining used petroleum lubricating oils.. Manufacture of petroleum lubricating oil.Lubricating oils, blending.
# Name: Text Content, dtype: object
# Error: index 0 is out of bounds for axis 0 with size 0
# SSIC in Master List: 19202
# recSSICDescription:
# 0    Building and repairing of ships, tankers and other ocean-going vessels (including conversion of ships into off-shore structures).This Sub-class includes the building and/or repairing of ships, except vessels for sports or recreation, and/or the construction of floating structures such as floating cranes and/or drilling platforms. This Sub-class also includes - manufacture of sections for ships and/or floating structures - building and/or repairing of: - commercial vessels: passenger vessels, ferry boats, cargo ships, tankers, tugs, etc. - warships - fishing boats and/or fish-processing factory vessels - hovercraft (except recreation-type hovercraft) - ship parts - construction of: - drilling platforms, floating or submersible - floating structures (e.g. floating docks, pontoons, coffer-dams, floating landing stages, buoys, floating tanks, barges, floating cranes, non-recreational inflatable rafts). Building and repairing of ships, tankers and other ocean-going vessels (including conversion of ships into off-shore structures).Barge building. Building and repairing of ships, tankers and other ocean-going vessels (including conversion of ships into off-shore structures).Barge repairing. Building and repairing of ships, tankers and other ocean-going vessels (including conversion of ships into off-shore structures).Conversion of ships into off-shore structures. Building and repairing of ships, tankers and other ocean-going vessels (including conversion of ships into off-shore structures).Sandblasting works (ships). Building and repairing of ships, tankers and other ocean-going vessels (including conversion of ships into off-shore structures).Ship parts manufacturing. Building and repairing of ships, tankers and other ocean-going vessels (including conversion of ships into off-shore structures).Ship parts repair and maintenance. Building and repairing of ships, tankers and other ocean-going vessels (including conversion of ships into off-shore structures).Ship repairing. Building and repairing of ships, tankers and other ocean-going vessels (including conversion of ships into off-shore structures).Shipbuilding. Building and repairing of ships, tankers and other ocean-going vessels (including conversion of ships into off-shore structures).Shipyard. Building and repairing of ships, tankers and other ocean-going vessels (including conversion of ships into off-shore structures).Tanker building. Building and repairing of ships, tankers and other ocean-going vessels (including conversion of ships into off-shore structures).Tanker repairing.
# Name: Text Content, dtype: object
# Error: index 0 is out of bounds for axis 0 with size 0
# SSIC in Master List: 30110
# Model Results:
# Accuracy of Recommendation Model: 30.8%
# Overall Similarity Score: 0.62 out of 1.00
# Overall Stats (99 Divisions in Total):
# mean    49.1
# std     17.0
# dtype: float64
# Model Results:
# Accuracy of Recommendation Model: 26.9%
# Overall Similarity Score: 0.56 out of 1.00
# Overall Stats (99 Divisions in Total):
# mean    53.9
# std     18.4
# dtype: float64
# actualSSICDescription:
# Series([], Name: Text Content, dtype: object)
# Error: index 0 is out of bounds for axis 0 with size 0
# SSIC in Master List: 00nan
# actualSSICDescription:
# Series([], Name: Text Content, dtype: object)
# Error: index 0 is out of bounds for axis 0 with size 0
# SSIC in Master List: 00nan
# actualSSICDescription:
# Series([], Name: Text Content, dtype: object)
# Error: index 0 is out of bounds for axis 0 with size 0
# SSIC in Master List: 00nan
# actualSSICDescription:
# Series([], Name: Text Content, dtype: object)
# Error: index 0 is out of bounds for axis 0 with size 0
# SSIC in Master List: 00nan
# actualSSICDescription:
# Series([], Name: Text Content, dtype: object)
# Error: index 0 is out of bounds for axis 0 with size 0
# SSIC in Master List: 00nan
# Model Results:
# Accuracy of Recommendation Model: 42.3%
# Overall Similarity Score: 0.59 out of 1.00
# Overall Stats (99 Divisions in Total):
# mean    46.4
# std     16.7
# dtype: float64
# recSSICDescription:
# 0    Retail sale of lighting and lighting accessories.This Sub-class includes retail sale of lighting and/or lighting accessories.. Retail sale of lighting and lighting accessories.Lighting and lighting accessories e-commerce retailer (with income mainly from online sales). Retail sale of lighting and lighting accessories.Lighting and lighting accessories online retailer (with income mainly from online sales). Retail sale of lighting and lighting accessories.Lighting and lighting accessories retail sale via internet (with income mainly from online sales). Retail sale of lighting and lighting accessories.Lighting and lighting accessories retail sale via vending machine (with income mainly from vending machine sales). Retail sale of lighting and lighting accessories.Lighting and lighting accessories retail sale via mail order (with income mainly from mail order sales). Retail sale of lighting and lighting accessories.Lighting and lighting accessories retail sale via door-to-door canvassing (with income mainly from door-to-door sales). Retail sale of lighting and lighting accessories.Lighting and lighting accessories retail sale via television (with income mainly from sales on TV). Retail sale of lighting and lighting accessories.Lighting and lighting accessories retail sale via brick-and-mortar shops (with income mainly from sales at brick-and-mortar stores). Retail sale of lighting and lighting accessories.Bulb, electric light, retailing. Retail sale of lighting and lighting accessories.Electric bulb retailing. Retail sale of lighting and lighting accessories.Electric lighting fixture retailing. Retail sale of lighting and lighting accessories.Electrical lamp retailing. Retail sale of lighting and lighting accessories.Lamp and tube, electrical, retailing. Retail sale of lighting and lighting accessories.Lighting fixture, electrical, retailing.
# Name: Text Content, dtype: object
# Error: index 0 is out of bounds for axis 0 with size 0
# SSIC in Master List: 47533
# Model Results:
# Accuracy of Recommendation Model: 19.2%
# Overall Similarity Score: 0.6 out of 1.00
# Overall Stats (99 Divisions in Total):
# mean    53.4
# std     18.0
# dtype: float64
# recSSICDescription:
# 0    Building and repairing of ships, tankers and other ocean-going vessels (including conversion of ships into off-shore structures).This Sub-class includes the building and/or repairing of ships, except vessels for sports or recreation, and/or the construction of floating structures such as floating cranes and/or drilling platforms. This Sub-class also includes - manufacture of sections for ships and/or floating structures - building and/or repairing of: - commercial vessels: passenger vessels, ferry boats, cargo ships, tankers, tugs, etc. - warships - fishing boats and/or fish-processing factory vessels - hovercraft (except recreation-type hovercraft) - ship parts - construction of: - drilling platforms, floating or submersible - floating structures (e.g. floating docks, pontoons, coffer-dams, floating landing stages, buoys, floating tanks, barges, floating cranes, non-recreational inflatable rafts). Building and repairing of ships, tankers and other ocean-going vessels (including conversion of ships into off-shore structures).Barge building. Building and repairing of ships, tankers and other ocean-going vessels (including conversion of ships into off-shore structures).Barge repairing. Building and repairing of ships, tankers and other ocean-going vessels (including conversion of ships into off-shore structures).Conversion of ships into off-shore structures. Building and repairing of ships, tankers and other ocean-going vessels (including conversion of ships into off-shore structures).Sandblasting works (ships). Building and repairing of ships, tankers and other ocean-going vessels (including conversion of ships into off-shore structures).Ship parts manufacturing. Building and repairing of ships, tankers and other ocean-going vessels (including conversion of ships into off-shore structures).Ship parts repair and maintenance. Building and repairing of ships, tankers and other ocean-going vessels (including conversion of ships into off-shore structures).Ship repairing. Building and repairing of ships, tankers and other ocean-going vessels (including conversion of ships into off-shore structures).Shipbuilding. Building and repairing of ships, tankers and other ocean-going vessels (including conversion of ships into off-shore structures).Shipyard. Building and repairing of ships, tankers and other ocean-going vessels (including conversion of ships into off-shore structures).Tanker building. Building and repairing of ships, tankers and other ocean-going vessels (including conversion of ships into off-shore structures).Tanker repairing.
# Name: Text Content, dtype: object
# Error: index 0 is out of bounds for axis 0 with size 0
# SSIC in Master List: 30110
# recSSICDescription:
# 0    Bank/Financial holding companies (including insurance holding company).This Sub-class includes the activities of bank/financial holding companies, i.e. units that hold the assets (owning controlling-levels of equity) of a group of subsidiary corporations and whose principal activity is owning the group. The holding companies in this Sub-class generally do not provide any other service to the businesses in which the equity is held, i.e. they do not administer or manage other units.. Bank/Financial holding companies (including insurance holding company).Bank/Financial holding company. Bank/Financial holding companies (including insurance holding company).Insurance holding company.
# Name: Text Content, dtype: object
# Error: index 0 is out of bounds for axis 0 with size 0
# SSIC in Master List: 64201
# Model Results:
# Accuracy of Recommendation Model: 23.1%
# Overall Similarity Score: 0.56 out of 1.00
# Overall Stats (99 Divisions in Total):
# mean    53.0
# std     19.0
# dtype: float64
# recSSICDescription:
# 0    Airlines (passenger).This Sub-class includes the provision of air transportation of passengers over regular routes and on regular schedules.. Airlines (passenger).Airline (passenger) service. Airlines (passenger).Passenger carrier service, air.
# Name: Text Content, dtype: object
# Error: index 0 is out of bounds for axis 0 with size 0
# SSIC in Master List: 51001
# Model Results:
# Accuracy of Recommendation Model: 34.6%
# Overall Similarity Score: 0.56 out of 1.00
# Overall Stats (99 Divisions in Total):
# mean    50.2
# std     17.5
# dtype: float64
# Model Results:
# Accuracy of Recommendation Model: 50.0%
# Overall Similarity Score: 0.59 out of 1.00
# Overall Stats (99 Divisions in Total):
# mean    56.0
# std     16.2
# dtype: float64
# recSSICDescription:
# 0    Real estate developers.This Sub-class includes: - the development of land with the eventual aim of selling the residential or commercial properties - buying and/or selling of properties or land. Real estate developers.Development company (real estate). Real estate developers.Real estate development service.
# Name: Text Content, dtype: object
# Error: index 0 is out of bounds for axis 0 with size 0
# SSIC in Master List: 68101
# Model Results:
# Accuracy of Recommendation Model: 19.2%
# Overall Similarity Score: 0.59 out of 1.00
# Overall Stats (99 Divisions in Total):
# mean    47.5
# std     15.7
# dtype: float64
# actualSSICDescription:
# Series([], Name: Text Content, dtype: object)
# Error: index 0 is out of bounds for axis 0 with size 0
# SSIC in Master List: 00nan
# actualSSICDescription:
# Series([], Name: Text Content, dtype: object)
# Error: index 0 is out of bounds for axis 0 with size 0
# SSIC in Master List: 00nan
# actualSSICDescription:
# Series([], Name: Text Content, dtype: object)
# Error: index 0 is out of bounds for axis 0 with size 0
# SSIC in Master List: 00nan
# actualSSICDescription:
# Series([], Name: Text Content, dtype: object)
# Error: index 0 is out of bounds for axis 0 with size 0
# SSIC in Master List: 00nan
# actualSSICDescription:
# Series([], Name: Text Content, dtype: object)
# Error: index 0 is out of bounds for axis 0 with size 0
# SSIC in Master List: 00nan
# Model Results:
# Accuracy of Recommendation Model: 34.6%
# Overall Similarity Score: 0.58 out of 1.00
# Overall Stats (99 Divisions in Total):
# mean    44.3
# std     12.8
# dtype: float64
# recSSICDescription:
# 0    Construction of other civil engineering projects n.e.c. (e.g. playground systems).This Sub-class includes activities of civil engineering construction projects not elsewhere classified..- aeroplane hangar construction - airport construction - playground systems construction Construction of other civil engineering projects n.e.c. (e.g. playground systems).Aeroplane hangar construction. Construction of other civil engineering projects n.e.c. (e.g. playground systems).Airport construction. Construction of other civil engineering projects n.e.c. (e.g. playground systems).General engineering construction. Construction of other civil engineering projects n.e.c. (e.g. playground systems).Long distance local pipeline construction. Construction of other civil engineering projects n.e.c. (e.g. playground systems).Long distance pipeline construction for mining activities. Construction of other civil engineering projects n.e.c. (e.g. playground systems).Mining activities (long distance) pipeline construction. Construction of other civil engineering projects n.e.c. (e.g. playground systems).Playground systems construction. Construction of other civil engineering projects n.e.c. (e.g. playground systems).Water well drilling. Construction of other civil engineering projects n.e.c. (e.g. playground systems).Long distance pipeline construction for use in local pipelines and mining activities. Construction of other civil engineering projects n.e.c. (e.g. playground systems).Outdoor sports facilities construction.
# Name: Text Content, dtype: object
# Error: index 0 is out of bounds for axis 0 with size 0
# SSIC in Master List: 42909
# recSSICDescription:
# 0    Wholesale trade of a variety of goods without a dominant product.This Sub-class includes wholesale of a variety of goods without a dominant product.. Wholesale trade of a variety of goods without a dominant product.General importer and exporter of a variety of goods without a dominant product. Wholesale trade of a variety of goods without a dominant product.General trading of a variety of goods without a dominant product. Wholesale trade of a variety of goods without a dominant product.General wholesale trade of a variety of goods without a dominant product.
# Name: Text Content, dtype: object
# Error: index 0 is out of bounds for axis 0 with size 0
# SSIC in Master List: 46900
# recSSICDescription:
# 0    Building and repairing of ships, tankers and other ocean-going vessels (including conversion of ships into off-shore structures).This Sub-class includes the building and/or repairing of ships, except vessels for sports or recreation, and/or the construction of floating structures such as floating cranes and/or drilling platforms. This Sub-class also includes - manufacture of sections for ships and/or floating structures - building and/or repairing of: - commercial vessels: passenger vessels, ferry boats, cargo ships, tankers, tugs, etc. - warships - fishing boats and/or fish-processing factory vessels - hovercraft (except recreation-type hovercraft) - ship parts - construction of: - drilling platforms, floating or submersible - floating structures (e.g. floating docks, pontoons, coffer-dams, floating landing stages, buoys, floating tanks, barges, floating cranes, non-recreational inflatable rafts). Building and repairing of ships, tankers and other ocean-going vessels (including conversion of ships into off-shore structures).Barge building. Building and repairing of ships, tankers and other ocean-going vessels (including conversion of ships into off-shore structures).Barge repairing. Building and repairing of ships, tankers and other ocean-going vessels (including conversion of ships into off-shore structures).Conversion of ships into off-shore structures. Building and repairing of ships, tankers and other ocean-going vessels (including conversion of ships into off-shore structures).Sandblasting works (ships). Building and repairing of ships, tankers and other ocean-going vessels (including conversion of ships into off-shore structures).Ship parts manufacturing. Building and repairing of ships, tankers and other ocean-going vessels (including conversion of ships into off-shore structures).Ship parts repair and maintenance. Building and repairing of ships, tankers and other ocean-going vessels (including conversion of ships into off-shore structures).Ship repairing. Building and repairing of ships, tankers and other ocean-going vessels (including conversion of ships into off-shore structures).Shipbuilding. Building and repairing of ships, tankers and other ocean-going vessels (including conversion of ships into off-shore structures).Shipyard. Building and repairing of ships, tankers and other ocean-going vessels (including conversion of ships into off-shore structures).Tanker building. Building and repairing of ships, tankers and other ocean-going vessels (including conversion of ships into off-shore structures).Tanker repairing.
# Name: Text Content, dtype: object
# Error: index 0 is out of bounds for axis 0 with size 0
# SSIC in Master List: 30110
# Model Results:
# Accuracy of Recommendation Model: 34.6%
# Overall Similarity Score: 0.59 out of 1.00
# Overall Stats (99 Divisions in Total):
# mean    49.6
# std     17.0
# dtype: float64

# %% [markdown]
# ### LinkedIn + PDF

# %%
combined_df = pd.merge(pdf, df, how = 'left', on = 'Company')
combined_df = combined_df[combined_df.ssic_code_x.notnull()]
combined_df['Text Content_y'] = combined_df['Text Content_y'].apply(lambda x: '' if pd.isnull(x) else x)
combined_df['Text Content'] = combined_df['Text Content_x'] + '.' + combined_df['Text Content_y']
combined_df.drop(columns = ['ssic_code_y', 'Text Content_x', 'Text Content_y'], inplace=True)
combined_df.rename(columns = {'ssic_code_x': 'ssic_code'}, inplace = True)

# %%
accuracy = 0
for i in range(1,11):
# while accuracy < 0.55:
    recsys_df, recsysStats_df, recsysForValidation_df, training_df, testing_df, model, modelResults_df = recommendationModel(df = combined_df, ssic = ssic,
                                                                                                    withSSIC = True, epochs = 40, vector_size = 64,
                                                                                                    top = 5, trainPercentage_0to1 = 0.7)
    accuracy = float(modelResults_df.head(1)['Values'].values[0])

# Create files
with pd.ExcelWriter(linkedInPdfModelResults_path) as writer:
    modelResults_df.to_excel(writer, sheet_name='Model Results', index=False)
    recsys_df.to_excel(writer, sheet_name='Model Outputs', index=False)
    recsysStats_df.to_excel(writer, sheet_name='Model Stats', index=False)
    recsysForValidation_df.to_excel(writer, sheet_name='Model Validation', index=False)
    training_df.to_excel(writer, sheet_name='Training Data', index=False)
    testing_df.to_excel(writer, sheet_name='Testing Data', index=False)
model.save(linkedInPdfModel_path)
# Out:
# actualSSICDescription:
# Series([], Name: Text Content, dtype: object)
# Error: index 0 is out of bounds for axis 0 with size 0
# SSIC in Master List: 00nan
# actualSSICDescription:
# Series([], Name: Text Content, dtype: object)
# Error: index 0 is out of bounds for axis 0 with size 0
# SSIC in Master List: 00nan
# actualSSICDescription:
# Series([], Name: Text Content, dtype: object)
# Error: index 0 is out of bounds for axis 0 with size 0
# SSIC in Master List: 00nan
# actualSSICDescription:
# Series([], Name: Text Content, dtype: object)
# Error: index 0 is out of bounds for axis 0 with size 0
# SSIC in Master List: 00nan
# actualSSICDescription:
# Series([], Name: Text Content, dtype: object)
# Error: index 0 is out of bounds for axis 0 with size 0
# SSIC in Master List: 00nan
# Model Results:
# Accuracy of Recommendation Model: 38.5%
# Overall Similarity Score: 0.55 out of 1.00
# Overall Stats (99 Divisions in Total):
# mean    50.4
# std     19.1
# dtype: float64
# actualSSICDescription:
# Series([], Name: Text Content, dtype: object)
# Error: index 0 is out of bounds for axis 0 with size 0
# SSIC in Master List: 00nan
# actualSSICDescription:
# Series([], Name: Text Content, dtype: object)
# Error: index 0 is out of bounds for axis 0 with size 0
# SSIC in Master List: 00nan
# actualSSICDescription:
# Series([], Name: Text Content, dtype: object)
# Error: index 0 is out of bounds for axis 0 with size 0
# SSIC in Master List: 00nan
# actualSSICDescription:
# Series([], Name: Text Content, dtype: object)
# Error: index 0 is out of bounds for axis 0 with size 0
# SSIC in Master List: 00nan
# actualSSICDescription:
# Series([], Name: Text Content, dtype: object)
# Error: index 0 is out of bounds for axis 0 with size 0
# SSIC in Master List: 00nan
# Model Results:
# Accuracy of Recommendation Model: 53.8%
# Overall Similarity Score: 0.6 out of 1.00
# Overall Stats (99 Divisions in Total):
# mean    49.2
# std     17.9
# dtype: float64
# actualSSICDescription:
# Series([], Name: Text Content, dtype: object)
# Error: index 0 is out of bounds for axis 0 with size 0
# SSIC in Master List: 00nan
# actualSSICDescription:
# Series([], Name: Text Content, dtype: object)
# Error: index 0 is out of bounds for axis 0 with size 0
# SSIC in Master List: 00nan
# actualSSICDescription:
# Series([], Name: Text Content, dtype: object)
# Error: index 0 is out of bounds for axis 0 with size 0
# SSIC in Master List: 00nan
# actualSSICDescription:
# Series([], Name: Text Content, dtype: object)
# Error: index 0 is out of bounds for axis 0 with size 0
# SSIC in Master List: 00nan
# actualSSICDescription:
# Series([], Name: Text Content, dtype: object)
# Error: index 0 is out of bounds for axis 0 with size 0
# SSIC in Master List: 00nan
# Model Results:
# Accuracy of Recommendation Model: 19.2%
# Overall Similarity Score: 0.58 out of 1.00
# Overall Stats (99 Divisions in Total):
# mean    47.9
# std     17.4
# dtype: float64
# actualSSICDescription:
# Series([], Name: Text Content, dtype: object)
# Error: index 0 is out of bounds for axis 0 with size 0
# SSIC in Master List: 00nan
# actualSSICDescription:
# Series([], Name: Text Content, dtype: object)
# Error: index 0 is out of bounds for axis 0 with size 0
# SSIC in Master List: 00nan
# actualSSICDescription:
# Series([], Name: Text Content, dtype: object)
# Error: index 0 is out of bounds for axis 0 with size 0
# SSIC in Master List: 00nan
# actualSSICDescription:
# Series([], Name: Text Content, dtype: object)
# Error: index 0 is out of bounds for axis 0 with size 0
# SSIC in Master List: 00nan
# actualSSICDescription:
# Series([], Name: Text Content, dtype: object)
# Error: index 0 is out of bounds for axis 0 with size 0
# SSIC in Master List: 00nan
# Model Results:
# Accuracy of Recommendation Model: 38.5%
# Overall Similarity Score: 0.6 out of 1.00
# Overall Stats (99 Divisions in Total):
# mean    46.3
# std     18.1
# dtype: float64
# Model Results:
# Accuracy of Recommendation Model: 26.9%
# Overall Similarity Score: 0.56 out of 1.00
# Overall Stats (99 Divisions in Total):
# mean    49.2
# std     17.1
# dtype: float64
# actualSSICDescription:
# Series([], Name: Text Content, dtype: object)
# Error: index 0 is out of bounds for axis 0 with size 0
# SSIC in Master List: 00nan
# actualSSICDescription:
# Series([], Name: Text Content, dtype: object)
# Error: index 0 is out of bounds for axis 0 with size 0
# SSIC in Master List: 00nan
# actualSSICDescription:
# Series([], Name: Text Content, dtype: object)
# Error: index 0 is out of bounds for axis 0 with size 0
# SSIC in Master List: 00nan
# actualSSICDescription:
# Series([], Name: Text Content, dtype: object)
# Error: index 0 is out of bounds for axis 0 with size 0
# SSIC in Master List: 00nan
# actualSSICDescription:
# Series([], Name: Text Content, dtype: object)
# Error: index 0 is out of bounds for axis 0 with size 0
# SSIC in Master List: 00nan
# Model Results:
# Accuracy of Recommendation Model: 30.8%
# Overall Similarity Score: 0.56 out of 1.00
# Overall Stats (99 Divisions in Total):
# mean    48.9
# std     18.9
# dtype: float64
# recSSICDescription:
# 0    Hotels.This Sub-class includes: - the provision of furnished accommodation in hotels, typically on a daily or weekly basis, principally for short stay by visitors - Examples of facilities and/or services provided: - daily or other regular housekeeping services - food and beverage services in restaurants on the premises - laundry services - swimming pools and/or exercise rooms - conference and/or convention facilities - provision of hotel management services (i.e. providing management and operating staff to run hotel). Hotels.Hotels.
# Name: Text Content, dtype: object
# Error: index 0 is out of bounds for axis 0 with size 0
# SSIC in Master List: 55101
# Model Results:
# Accuracy of Recommendation Model: 30.8%
# Overall Similarity Score: 0.59 out of 1.00
# Overall Stats (99 Divisions in Total):
# mean    53.5
# std     18.8
# dtype: float64
# recSSICDescription:
# 0    Other business support service activities (e.g. administration of loyalty programmes).This Sub-class includes the provision of other business support services that are not elsewhere classified..- addressograph service - administration of loyalty programme - diving service on a contract or fee basis (non-sports instructional) Other business support service activities (e.g. administration of loyalty programmes).Addressograph service. Other business support service activities (e.g. administration of loyalty programmes).Administration of loyalty programme. Other business support service activities (e.g. administration of loyalty programmes).Diving service on a contract or fee basis (non-sports instructional). Other business support service activities (e.g. administration of loyalty programmes).Fund raising services on a contract or fee basis. Other business support service activities (e.g. administration of loyalty programmes).Printing broker. Other business support service activities (e.g. administration of loyalty programmes).Repossession service. Other business support service activities (e.g. administration of loyalty programmes).Weighing machine operation. Other business support service activities (e.g. administration of loyalty programmes).Fundraising services on a contract and fee basis. Other business support service activities (e.g. administration of loyalty programmes).Repossession services.
# Name: Text Content, dtype: object
# Error: index 0 is out of bounds for axis 0 with size 0
# SSIC in Master List: 82999
# recSSICDescription:
# 0    Other business support service activities (e.g. administration of loyalty programmes).This Sub-class includes the provision of other business support services that are not elsewhere classified..- addressograph service - administration of loyalty programme - diving service on a contract or fee basis (non-sports instructional) Other business support service activities (e.g. administration of loyalty programmes).Addressograph service. Other business support service activities (e.g. administration of loyalty programmes).Administration of loyalty programme. Other business support service activities (e.g. administration of loyalty programmes).Diving service on a contract or fee basis (non-sports instructional). Other business support service activities (e.g. administration of loyalty programmes).Fund raising services on a contract or fee basis. Other business support service activities (e.g. administration of loyalty programmes).Printing broker. Other business support service activities (e.g. administration of loyalty programmes).Repossession service. Other business support service activities (e.g. administration of loyalty programmes).Weighing machine operation. Other business support service activities (e.g. administration of loyalty programmes).Fundraising services on a contract and fee basis. Other business support service activities (e.g. administration of loyalty programmes).Repossession services.
# Name: Text Content, dtype: object
# Error: index 0 is out of bounds for axis 0 with size 0
# SSIC in Master List: 82999
# recSSICDescription:
# 0    Hotels.This Sub-class includes: - the provision of furnished accommodation in hotels, typically on a daily or weekly basis, principally for short stay by visitors - Examples of facilities and/or services provided: - daily or other regular housekeeping services - food and beverage services in restaurants on the premises - laundry services - swimming pools and/or exercise rooms - conference and/or convention facilities - provision of hotel management services (i.e. providing management and operating staff to run hotel). Hotels.Hotels.
# Name: Text Content, dtype: object
# Error: index 0 is out of bounds for axis 0 with size 0
# SSIC in Master List: 55101
# Model Results:
# Accuracy of Recommendation Model: 42.3%
# Overall Similarity Score: 0.58 out of 1.00
# Overall Stats (99 Divisions in Total):
# mean    46.9
# std     18.5
# dtype: float64
# actualSSICDescription:
# Series([], Name: Text Content, dtype: object)
# Error: index 0 is out of bounds for axis 0 with size 0
# SSIC in Master List: 00nan
# actualSSICDescription:
# Series([], Name: Text Content, dtype: object)
# Error: index 0 is out of bounds for axis 0 with size 0
# SSIC in Master List: 00nan
# actualSSICDescription:
# Series([], Name: Text Content, dtype: object)
# Error: index 0 is out of bounds for axis 0 with size 0
# SSIC in Master List: 00nan
# actualSSICDescription:
# Series([], Name: Text Content, dtype: object)
# Error: index 0 is out of bounds for axis 0 with size 0
# SSIC in Master List: 00nan
# actualSSICDescription:
# Series([], Name: Text Content, dtype: object)
# Error: index 0 is out of bounds for axis 0 with size 0
# SSIC in Master List: 00nan
# Model Results:
# Accuracy of Recommendation Model: 38.5%
# Overall Similarity Score: 0.57 out of 1.00
# Overall Stats (99 Divisions in Total):
# mean    47.8
# std     17.8
# dtype: float64
# Model Results:
# Accuracy of Recommendation Model: 42.3%
# Overall Similarity Score: 0.6 out of 1.00
# Overall Stats (99 Divisions in Total):
# mean    48.5
# std     17.3
# dtype: float64
